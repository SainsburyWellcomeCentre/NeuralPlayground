# %%
import numpy as np
import matplotlib.pyplot as plt
from env_list.simple2d import Simple2D, Sargolini2006, BasicSargolini2006

# %%
room_width = 15
room_depth = 7
env_name = "env_example"
time_step_size = 0.1 #seg
agent_step_size = 0.5

# Init environment
env = Simple2D(environment_name=env_name,
               room_width = room_width,
               room_depth = room_depth,
               time_step_size = time_step_size,
               agent_step_size = agent_step_size)

# %%
# Create random agent
class RandomAgent(object):
    
    def act(self, observation):
        return np.random.normal(scale=0.1, size=(2,))
    
agent = RandomAgent()

# %%
n_steps = 1000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()
# Out:
# [0 0]

# %%
data_path = "experiment_data/sargolini2006/"
env = BasicSargolini2006(data_path = data_path, 
                         time_step_size = 0.1,
                         agent_step_size = None)
# Out:
# ../environments/experiment_data/behavioral_data.py:34: RuntimeWarning: invalid value encountered in true_divide
#   head_direction = head_direction/np.sqrt(np.sum(head_direction**2, axis=1))[..., np.newaxis]

# %%
n_steps = 1000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()
# Out:
# [ 32.28176299 -29.72747824  -0.71510282   0.69901928]

# %%
data_path = "/home/rodrigo/HDisk/8F6BE356-3277-475C-87B1-C7A977632DA7_1/all_data/"

session = {"rat_id": "11016", "sess": "31010502"}

env = Sargolini2006(data_path = data_path,
                    verbose = True,
                    session = session,
                    time_step_size = None,
                    agent_step_size = None)
# Out:
# The sample includes conjunctive cells and head direction cells from layers III and V of medial entorhinal cortex and have  been published in
# Sargolini et al. (Science, 2006).
#
# The files are in matlab format. They include spike and position times for recorded cells from rats that were running in a 1 x 1 m
# enclosure. The cells were recorded in the dorsocaudal 25% portion of the medial entorhinal cortex. Position is given for two LEDs
# to enable calculation of head direction.
#
# The cell id is based on tetrode number and cell number (i.e: t2c7).
#
# The file naming convention is as follow:
#
# Rat number - session number _ cell id (i.e: 11084-03020501_t2c1).
#
# Each session duration is normally 10 minutes, but some sessions are combination of 2 or more 10 minutes sessions, this is marked in
# the file name by using "+" between the session numbers (i.e: 11207-21060501+02_t6c1). Note that the 6 first digits in the session
# number is the date of the recording.
#
# When loading the files into Matlab you get the following variables:
#
# x1	Array with the x-positions for the first tracking LED.
# y1	Array with the y-positions for the first tracking LED.
# x2	Array with the x-positions for the second tracking LED.
# y2	Array with the y-positions for the second tracking LED.
# t	Array with the position timestamps.
# ts	Array with the cell spike timestamps.
#
# The position data have been smoothed with a moving mean filter to remove tracking jitter.
#
#
# You can use the data for whatever you want but we take no responsibility for what is published!
#
# Please refer to our web site where you obtained the data in your Methods section when you write up the results.
#
# Best regards,
#
# Raymond Skjerpeng and Edvard Moser
# Kavli Institute for Systems Neuroscience
# Centre for the Biology of Memory
# Norwegian University of Science and Technology
#
# Correspondence: Edvard Moser (edvard.moser@ntnu.no)
#
# Rat ids ['10073', '10697', '10704', '10884', '10938', '10962', '11016', '11025', '11084', '11138', '11207', '11265', '11278', '11340', '11343']
# Sessions for 10073
# ['17010302']
# Cells recorded in session 17010302
# ['T1C1', 'T2C1', 'T2C3', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'T4C1', 'position']
# Sessions for 10697
# ['02030402', '24020402']
# Cells recorded in session 02030402
# ['T1C1', 'T1C2', 'T1C3', 'T2C1', 'T2C3', 'position']
# Cells recorded in session 24020402
# ['T1C1', 'T1C2', 'T1C3', 'T2C1', 'T2C2', 'position']
# Sessions for 10704
# ['06070402', '07070402', '07070407', '08070402', '19070402', '20060402', '20070402', '23060402', '25060402', '26060402']
# Cells recorded in session 06070402
# ['T2C1', 'T2C2', 'T2C3', 'position']
# Cells recorded in session 07070402
# ['T1C1', 'T2C3', 'T2C4', 'T4C1', 'position']
# Cells recorded in session 07070407
# ['T2C1', 'T2C2', 'T2C3', 'T2C4', 'T2C5', 'T2C6', 'position']
# Cells recorded in session 08070402
# ['T1C1', 'T1C2', 'T1C3', 'T2C1', 'T4C1', 'T4C2', 'T4C5', 'position']
# Cells recorded in session 19070402
# ['T2C1', 'T2C5', 'position']
# Cells recorded in session 20060402
# ['T1C1', 'T1C3', 'T1C4', 'T2C1', 'T2C2', 'T2C3', 'T3C1', 'T3C2', 'T3C3', 'position']
# Cells recorded in session 20070402
# ['T2C1', 'T4C1', 'position']
# Cells recorded in session 23060402
# ['T1C1', 'T1C2', 'T1C3', 'position']
# Cells recorded in session 25060402
# ['T2C1', 'T2C3', 'T2C4', 'position']
# Cells recorded in session 26060402
# ['T2C1', 'T2C2', 'T2C3', 'T2C5', 'T3C1', 'position']
# Sessions for 10884
# ['01080402', '02080405', '03080402', '03080405', '03080409', '04080402', '05080401', '08070402', '08070405', '09080404', '13070402', '14070405', '16070401', '19070401', '21070405', '24070401', '31070404']
# Cells recorded in session 01080402
# ['T3C1', 'T3C2', 'position']
# Cells recorded in session 02080405
# ['T3C1', 'T3C3', 'T3C5', 'position']
# Cells recorded in session 03080402
# ['T1C2', 'T3C2', 'T3C3', 'T4C1', 'T4C2', 'T4C3', 'position']
# Cells recorded in session 03080405
# ['T1C1', 'T3C2', 'T3C3', 'T3C4', 'position']
# Cells recorded in session 03080409
# ['T3C1', 'T3C2', 'T3C3', 'T4C1', 'position']
# Cells recorded in session 04080402
# ['T3C1', 'T3C2', 'T3C4', 'position']
# Cells recorded in session 05080401
# ['T2C1', 'T3C2', 'T3C4', 'position']
# Cells recorded in session 08070402
# ['T1C1', 'T2C1', 'T2C3', 'T3C1', 'position']
# Cells recorded in session 08070405
# ['T4C2', 'position']
# Cells recorded in session 09080404
# ['T3C1', 'T3C2', 'T3C3', 'T3C5', 'position']
# Cells recorded in session 13070402
# ['T2C1', 'T3C1', 'position']
# Cells recorded in session 14070405
# ['T1C1', 'T1C2', 'T3C3', 'position']
# Cells recorded in session 16070401
# ['T1C1', 'T2C1', 'position']
# Cells recorded in session 19070401
# ['T1C1', 'position']
# Cells recorded in session 21070405
# ['T3C1', 'T3C2', 'T3C3', 'position']
# Cells recorded in session 24070401
# ['T3C3', 'position']
# Cells recorded in session 31070404
# ['T4C1', 'position']
# Sessions for 10938
# ['08100401', '12100406', '12100410']
# Cells recorded in session 08100401
# ['T7C2', 'T7C3', 'T7C4', 'position']
# Cells recorded in session 12100406
# ['T7C1', 'T7C2', 'T7C3', 'T7C4', 'position']
# Cells recorded in session 12100410
# ['T7C1', 'position']
# Sessions for 10962
# ['27110403', '28110402', '28110406', '29110404']
# Cells recorded in session 27110403
# ['T2C1', 'T2C2', 'T2C3', 'T2C4', 'T3C1', 'position']
# Cells recorded in session 28110402
# ['T4C1', 'T4C2', 'position']
# Cells recorded in session 28110406
# ['T2C1', 'T4C1', 'T4C2', 'position']
# Cells recorded in session 29110404
# ['T1C1', 'position']
# Sessions for 11016
# ['02020502', '25010501', '28010501', '29010503', '31010502']
# Cells recorded in session 02020502
# ['T5C1', 'T7C1', 'position']
# Cells recorded in session 25010501
# ['T6C2', 'position']
# Cells recorded in session 28010501
# ['T1C2', 'position']
# Cells recorded in session 29010503
# ['T5C1', 'T6C1', 'T6C2', 'T7C1', 'position']
# Cells recorded in session 31010502
# ['T5C2', 'T6C1', 'T6C2', 'T6C3', 'T8C2', 'position']
# Sessions for 11025
# ['01060511', '06050501', '06050502', '11040501', '11040502', '14050501', '14050502', '16050501', '16050502', '19050503', '20050501']
# Cells recorded in session 01060511
# ['T7C1', 'T7C2', 'T8C1', 'position']
# Cells recorded in session 06050501
# ['T1C1', 'T1C2', 'T1C4', 'T2C1', 'T2C2', 'T2C3', 'T2C6', 'position']
# Cells recorded in session 06050502
# []
# Cells recorded in session 11040501
# ['T2C1', 'T4C1', 'T5C1', 'T5C2', 'T5C3', 'T8C1', 'position']
# Cells recorded in session 11040502
# []
# Cells recorded in session 14050501
# ['T1C1', 'T1C2', 'T2C1', 'position']
# Cells recorded in session 14050502
# []
# Cells recorded in session 16050501
# ['T1C1', 'T1C2', 'T2C1', 'T2C2', 'position']
# Cells recorded in session 16050502
# []
# Cells recorded in session 19050503
# ['T5C1', 'T6C1', 'T6C2', 'T6C3', 'T7C1', 'T7C2', 'T8C1', 'T8C2', 'position']
# Cells recorded in session 20050501
# ['T5C1', 'T6C1', 'T6C2', 'T7C1', 'T7C2', 'T8C1', 'T8C2', 'position']
# Sessions for 11084
# ['01030503', '02030502', '03020501', '08030506', '09030501', '09030503', '10030502', '23020502', '24020502', '28020501']
# Cells recorded in session 01030503
# ['T2C1', 'T2C2', 'T2C3', 'T2C4', 'T3C1', 'T3C2', 'T3C6', 'position']
# Cells recorded in session 02030502
# ['T1C1', 'T1C3', 'T1C4', 'T2C1', 'T2C4', 'T2C5', 'T2C6', 'position']
# Cells recorded in session 03020501
# ['T1C1', 'T2C1', 'T2C2', 'T3C1', 'T3C2', 'T4C1', 'position']
# Cells recorded in session 08030506
# ['T1C1', 'T1C4', 'T3C1', 'T4C1', 'T4C4', 'T4C5', 'position']
# Cells recorded in session 09030501
# ['T1C1', 'T1C2', 'T1C3', 'T2C1', 'T3C1', 'T3C2', 'position']
# Cells recorded in session 09030503
# ['T2C2', 'position']
# Cells recorded in session 10030502
# ['T1C1', 'T1C2', 'T1C6', 'T2C1', 'T2C3', 'T2C7', 'T3C1', 'T4C1', 'T4C3', 'position']
# Cells recorded in session 23020502
# ['T1C1', 'T2C1', 'T2C2', 'T2C3', 'T3C1', 'T3C3', 'T4C1', 'position']
# Cells recorded in session 24020502
# ['T3C1', 'T3C2', 'position']
# Cells recorded in session 28020501
# ['T2C1', 'T3C1', 'T3C2', 'position']
# Sessions for 11138
# ['05040502', '06040501', '06040507', '07040501', '08040501', '11040501', '11040504', '11040505', '11040509', '12110501', '13040502', '15040504', '15040505', '19040502', '20040502', '25040501', '26040501']
# Cells recorded in session 05040502
# ['T1C1', 'position']
# Cells recorded in session 06040501
# ['T1C1', 'T1C2', 'T1C3', 'position']
# Cells recorded in session 06040507
# ['T1C1', 'T1C2', 'T3C1', 'T8C1', 'T8C3', 'position']
# Cells recorded in session 07040501
# ['T1C2', 'T3C1', 'T8C1', 'position']
# Cells recorded in session 08040501
# ['T7C1', 'position']
# Cells recorded in session 11040501
# ['T5C1', 'T5C2', 'T8C1', 'position']
# Cells recorded in session 11040504
# ['T1C1', 'T1C2', 'T3C1', 'T3C2', 'position']
# Cells recorded in session 11040505
# []
# Cells recorded in session 11040509
# ['T5C1', 'T5C3', 'T7C1', 'T8C1', 'T8C2', 'position']
# Cells recorded in session 12110501
# ['T5C1', 'T6C1', 'T7C1', 'T8C1', 'position']
# Cells recorded in session 13040502
# ['T5C1', 'T6C1', 'T7C1', 'position']
# Cells recorded in session 15040504
# ['T1C1', 'T2C1', 'position']
# Cells recorded in session 15040505
# []
# Cells recorded in session 19040502
# ['T1C3', 'position']
# Cells recorded in session 20040502
# ['T3C2', 'T5C1', 'T5C2', 'T6C1', 'T6C2', 'T6C3', 'T6C4', 'position']
# Cells recorded in session 25040501
# ['T3C1', 'position']
# Cells recorded in session 26040501
# ['T3C1', 'T5C1', 'T6C1', 'position']
# Sessions for 11207
# ['03060501', '03060502', '04070501', '04070502', '05070501', '06070501', '06070502', '07070501', '07070502', '08060501', '08070504', '08070505', '09060501', '09060502', '09070501', '09070505', '09070506', '10070501', '10070503', '10070504', '11060501', '11060502', '11060503', '11060504', '14060501', '16060501', '17060501', '17060502', '18060501', '18060502', '20060501', '21060501', '21060502', '21060503', '23060501', '24060501', '24060502', '27060501', '27060504', '27060505', '30060501', '30060503', '30060504']
# Cells recorded in session 03060501
# ['T1C1', 'T1C2', 'T2C2', 'T2C4', 'T2C6', 'T4C1', 'T4C2', 'position']
# Cells recorded in session 03060502
# []
# Cells recorded in session 04070501
# ['T1C1', 'T1C2', 'T1C3', 'T1C4', 'T2C5', 'T3C1', 'T5C1', 'T7C1', 'position']
# Cells recorded in session 04070502
# []
# Cells recorded in session 05070501
# ['T1C1', 'T4C1', 'T6C1', 'position']
# Cells recorded in session 06070501
# ['T5C1', 'T5C2', 'T5C3', 'T5C5', 'T6C1', 'T6C2', 'T6C3', 'position']
# Cells recorded in session 06070502
# []
# Cells recorded in session 07070501
# ['T1C1', 'T1C2', 'T1C5', 'T2C1', 'T2C3', 'T2C4', 'T3C1', 'T3C2', 'position']
# Cells recorded in session 07070502
# []
# Cells recorded in session 08060501
# ['T3C1', 'T3C2', 'T3C5', 'position']
# Cells recorded in session 08070504
# ['T1C1', 'T1C2', 'T1C3', 'T1C4', 'T1C5', 'T2C1', 'T2C3', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'position']
# Cells recorded in session 08070505
# []
# Cells recorded in session 09060501
# ['T2C1', 'T4C1', 'T5C2', 'T5C4', 'T6C1', 'T6C2', 'T6C3', 'T6C4', 'T7C1', 'T7C2', 'position']
# Cells recorded in session 09060502
# []
# Cells recorded in session 09070501
# ['T7C1', 'position']
# Cells recorded in session 09070505
# ['T6C1', 'T8C2', 'position']
# Cells recorded in session 09070506
# []
# Cells recorded in session 10070501
# ['T7C1', 'T7C2', 'T7C3', 'T8C1', 'position']
# Cells recorded in session 10070503
# ['T6C3', 'T6C4', 'T7C3', 'position']
# Cells recorded in session 10070504
# []
# Cells recorded in session 11060501
# ['1C11', 'T1C2', 'T1C3', 'T1C4', 'T1C7', 'T1C8', 'T3C1', 'T6C2', 'T6C3', 'T6C4', 'T6C5', 'T8C1', 'position']
# Cells recorded in session 11060502
# ['1C12', 'position']
# Cells recorded in session 11060503
# ['T2C3', 'T3C1', 'T4C1', 'T4C2', 'position']
# Cells recorded in session 11060504
# []
# Cells recorded in session 14060501
# ['T1C1', 'T1C5', 'T2C1', 'T6C1', 'T6C2', 'T6C3', 'T6C6', 'T7C1', 'T7C4', 'position']
# Cells recorded in session 16060501
# ['T1C1', 'T1C2', 'T1C3', 'T2C2', 'T2C6', 'T3C4', 'T3C5', 'T3C7', 'T7C1', 'T8C1', 'position']
# Cells recorded in session 17060501
# ['T1C1', 'T2C1', 'T2C4', 'T5C1', 'T5C2', 'T5C6', 'T6C3', 'T7C4', 'position']
# Cells recorded in session 17060502
# []
# Cells recorded in session 18060501
# ['T2C1', 'T3C1', 'T4C1', 'T5C1', 'T5C2', 'T5C3', 'T5C6', 'T5C7', 'T5C8', 'T6C2', 'T6C4', 'T7C1', 'T7C2', 'T7C3', 'T7C4', 'T7C5', 'T7C7', 'T7C8', 'position']
# Cells recorded in session 18060502
# []
# Cells recorded in session 20060501
# ['T1C3', 'T1C5', 'T2C1', 'T3C1', 'T3C2', 'T3C5', 'T3C6', 'position']
# Cells recorded in session 21060501
# ['T6C1', 'T6C3', 'T6C4', 'T7C2', 'T8C1', 'position']
# Cells recorded in session 21060502
# []
# Cells recorded in session 21060503
# ['T1C1', 'T1C3', 'T1C6', 'T2C1', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'T3C5', 'T4C1', 'T4C2', 'T4C3', 'T8C1', 'position']
# Cells recorded in session 23060501
# ['T1C1', 'T1C2', 'T1C3', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'T3C5', 'T4C1', 'position']
# Cells recorded in session 24060501
# ['T1C1', 'T1C2', 'T1C3', 'T1C6', 'T2C1', 'T3C2', 'T3C3', 'T4C1', 'T7C1', 'position']
# Cells recorded in session 24060502
# []
# Cells recorded in session 27060501
# ['T1C1', 'T1C2', 'T1C3', 'T1C5', 'T2C1', 'T2C2', 'T2C4', 'T2C5', 'T3C1', 'T3C2', 'T3C4', 'T3C5', 'T8C1', 'T8C4', 'position']
# Cells recorded in session 27060504
# ['T6C1', 'T8C1', 'T8C4', 'position']
# Cells recorded in session 27060505
# []
# Cells recorded in session 30060501
# ['T1C1', 'T1C3', 'T1C4', 'T1C5', 'T2C1', 'T2C4', 'T3C1', 'T3C4', 'T4C2', 'T6C1', 'position']
# Cells recorded in session 30060503
# ['T6C1', 'position']
# Cells recorded in session 30060504
# []
# Sessions for 11265
# ['01020602', '02020601', '03020601', '06020601', '07020602', '09020601', '13020601', '16030601', '16030602', '16030604', '16030605', '31010601']
# Cells recorded in session 01020602
# ['T1C2', 'T1C4', 'T2C1', 'T3C2', 'T4C1', 'T4C4', 'T7C1', 'T8C1', 'T8C2', 'position']
# Cells recorded in session 02020601
# ['T1C1', 'T1C3', 'T1C4', 'T1C5', 'T4C1', 'T5C1', 'T5C3', 'T7C1', 'T7C2', 'T7C3', 'T8C1', 'position']
# Cells recorded in session 03020601
# ['T1C1', 'T1C2', 'T1C4', 'T2C4', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'T4C1', 'T4C2', 'T4C3', 'T7C1', 'position']
# Cells recorded in session 06020601
# ['T1C1', 'T1C2', 'T2C1', 'T2C2', 'T2C3', 'T2C4', 'T3C1', 'T3C3', 'T3C5', 'T3C6', 'T4C1', 'T4C2', 'T4C4', 'T4C5', 'T5C1', 'T5C3', 'T7C1', 'T7C2', 'T7C3', 'position']
# Cells recorded in session 07020602
# ['T2C1', 'T2C2', 'T4C1', 'T5C2', 'T5C3', 'T7C1', 'T7C2', 'T7C3', 'position']
# Cells recorded in session 09020601
# ['T1C1', 'T1C2', 'T2C1', 'T2C3', 'T4C1', 'T4C2', 'T4C3', 'T5C1', 'T5C5', 'T7C1', 'T7C2', 'T7C3', 'T8C1', 'position']
# Cells recorded in session 13020601
# ['T1C1', 'T1C2', 'T7C1', 'T7C2', 'T8C1', 'position']
# Cells recorded in session 16030601
# ['T1C3', 'T1C4', 'T2C1', 'T2C2', 'T2C3', 'T2C4', 'T3C2', 'T3C3', 'T3C4', 'T4C1', 'T4C2', 'T4C3', 'position']
# Cells recorded in session 16030602
# []
# Cells recorded in session 16030604
# ['T1C1', 'T1C5', 'T2C3', 'T2C4', 'T3C1', 'T3C2', 'T3C3', 'T3C4', 'T3C5', 'T4C1', 'T4C2', 'T4C3', 'T4C4', 'T4C5', 'position']
# Cells recorded in session 16030605
# []
# Cells recorded in session 31010601
# ['T1C2', 'T1C3', 'T4C1', 'T4C2', 'T4C3', 'T8C1', 'T8C2', 'T8C3', 'position']
# Sessions for 11278
# ['30080505', '31080502']
# Cells recorded in session 30080505
# ['T5C1', 'T5C2', 'T5C3', 'T7C1', 'T7C2', 'T7C3', 'position']
# Cells recorded in session 31080502
# ['T5C1', 'T5C2', 'T5C3', 'T5C4', 'T5C5', 'T6C1', 'T6C2', 'T6C3', 'T6C4', 'T7C1', 'T7C2', 'position']
# Sessions for 11340
# ['01120501', '22110501', '25110501']
# Cells recorded in session 01120501
# ['T7C1', 'T8C1', 'position']
# Cells recorded in session 22110501
# ['T7C1', 'T7C3', 'T7C4', 'T8C1', 'T8C3', 'position']
# Cells recorded in session 25110501
# ['T7C1', 'T8C1', 'T8C2', 'position']
# Sessions for 11343
# ['08120502']
# Cells recorded in session 08120502
# ['T1C1', 'T5C1', 'T7C1', 'position']

# %%
n_steps = 3000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()
# Out:
# [ 13.63770743 -50.           1.           0.        ]

# %%
env.data.plot_session()
