# %% [markdown]
# # Data example: Hafting 2008

# %% [markdown]
# In this notbook we provide easy example on how access to the experimental results such as Neural recording, behaviours, etc...
#
# Each data set is organised in recordings session with an attributed recording number (rec index), as given in a list at the initialisation of the class (if verbose is True).
#
#     - To plot a tetrode recording call .plot_recording_tetr(index)
#     - To plot the trajectory recording call .plot_trajectory(index)
#     - To get access to the expeimental details call .show_keys()

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from neuralplayground.experiments.hafting_2008_data import Hafting2008Data

# %%
fullhafting_data =  Hafting2008Data()
fullhafting_data.show_data()
fullhafting_data.plot_recording_tetr((10, 4))
fullhafting_data.plot_trajectory((10, 4))
# Out:
# Dataframe with recordings
#           rat_id   session                           recorded_vars
# rec_index
# 0          11015  13120410                   [EEG, position, t5c1]
# 1          11265  13030610        [EEG, EG2, position, t5c1, t8c2]
# 2          11265  15020610             [EEG, position, t3c2, t7c1]
# 3          11265  16030611  [EEG, EG2, position, t4c1, t4c2, t4c4]
# 4          11340  01120511              [EEG, EG2, position, t7c1]
# 5          11343  16120511              [EEG, EG2, position, t1c1]
# 6          11607  02110610              [EEG, EG2, position, t8c1]
# 7          11607  28110611    [EEG, EG2, EG3, EG4, position, t6c2]
# 8          11647  09010715    [EEG, EG2, EG3, EG4, position, t8c1]
# 9          11647  10010711    [EEG, EG2, EG3, EG4, position, t1c2]
# 10         11684  20020710   [EG2, EG3, EG4, position, t5c1, t8c1]
# [(array([-127.40657376, -127.40657376, -127.89482298, ...,   85.9583347 ,
#            85.9583347 ,   85.9583347 ]),
#   array([-3.56427788, -3.56427788, -2.58777945, ..., -4.54077632,
#          -4.54077632, -4.54077632]),
#   array([0.00000e+00, 2.00000e-02, 4.00000e-02, ..., 1.07594e+03,
#          1.07596e+03, 1.07598e+03])),
#  (array([-152.94258872, -152.94258872, -150.07859211, ...,  151.11838467,
#           153.02771575,  153.02771575]),
#   array([-6.81584599, -6.81584599, -4.42918215, ..., 11.80013198,
#          10.84546644, 10.84546644]),
#   array([0.00000e+00, 2.00000e-02, 4.00000e-02, ..., 1.52996e+03,
#          1.52998e+03, 1.53000e+03]))]

# %%
data_list = fullhafting_data.get_recording_data((0, 5, 3))

# %%
data_list
# Out:
# [[{'EEG': {'EEG': array([[-1],
#            [-1],
#            [15],
#            ...,
#            [23],
#            [16],
#            [28]], dtype=int16)},
#    'position': {'posx': array([[154.46702497],
#            [154.46702497],
#            [154.46702497],
#            ...,
#            [-94.44296782],
#            [-90.13491026],
#            [-90.13491026]]),
#     'posy': array([[ 3.58106033],
#            [ 3.58106033],
#            [ 4.53840645],
#            ...,
#            [-0.24832418],
#            [-0.72699724],
#            [-0.72699724]]),
#     'post': array([[0.0000e+00],
#            [2.0000e-02],
#            [4.0000e-02],
#            ...,
#            [5.9994e+02],
#            [5.9996e+02],
#            [5.9998e+02]])},
#    't5c1': {'ts': array([[  8.71960417],
#            [  8.72342708],
#            [  8.73361458],
#            ...,
#            [599.398875  ],
#            [599.52916667],
#            [599.53541667]])}},
#   ['EEG', 'position', 't5c1'],
#   {'rat_id': '11015', 'session': '13120410'}],
#  [{'EEG': {'EEG': array([[ -1],
#            [ -1],
#            [ 24],
#            ...,
#            [-68],
#            [-60],
#            [-63]], dtype=int16)},
#    'EG2': {'EEG': array([[  0],
#            [ -2],
#            [  6],
#            ...,
#            [-23],
#            [-55],
#            [-90]], dtype=int16)},
#    'position': {'posx': array([[-157.25109788],
#            [-158.18441493],
#            [-158.18441493],
#            ...,
#            [ -96.11883112],
#            [ -96.11883112],
#            [-100.31875785]]),
#     'posy': array([[16.47933355],
#            [15.5460165 ],
#            [15.5460165 ],
#            ...,
#            [-0.78703187],
#            [-0.78703187],
#            [-0.32037335]]),
#     'post': array([[0.00000e+00],
#            [2.00000e-02],
#            [4.00000e-02],
#            ...,
#            [1.19994e+03],
#            [1.19996e+03],
#            [1.19998e+03]])},
#    't1c1': {'ts': array([[   4.56996875],
#            [   4.60205208],
#            [   4.61826042],
#            ...,
#            [1198.54780208],
#            [1198.55448958],
#            [1198.57580208]])}},
#   ['EEG', 'EG2', 'position', 't1c1'],
#   {'rat_id': '11343', 'session': '16120511'}],
#  [{'EEG': {'EEG': array([[  0],
#            [ -1],
#            [-28],
#            ...,
#            [ 52],
#            [ 46],
#            [ 34]], dtype=int16)},
#    'EG2': {'EEG': array([[  0],
#            [ -1],
#            [-35],
#            ...,
#            [ 38],
#            [ 27],
#            [ 26]], dtype=int16)},
#    'position': {'posx': array([[151.57280868],
#            [151.57280868],
#            [151.57280868],
#            ...,
#            [-17.47555086],
#            [-14.6580782 ],
#            [-14.6580782 ]]),
#     'posy': array([[-4.87141913],
#            [-4.40184036],
#            [-4.40184036],
#            ...,
#            [ 2.64184129],
#            [ 3.58099884],
#            [ 3.58099884]]),
#     'post': array([[0.00000e+00],
#            [2.00000e-02],
#            [4.00000e-02],
#            ...,
#            [1.19994e+03],
#            [1.19996e+03],
#            [1.19998e+03]])},
#    't4c1': {'ts': array([[   1.85151042],
#            [  13.82677083],
#            [  13.95916667],
#            ...,
#            [1199.02946875],
#            [1199.03576042],
#            [1199.04264583]])},
#    't4c2': {'ts': array([[8.39239583e-01],
#            [1.45452083e+00],
#            [1.59841667e+00],
#            ...,
#            [1.19858647e+03],
#            [1.19933168e+03],
#            [1.19990126e+03]])},
#    't4c4': {'ts': array([[   1.39438542],
#            [   1.53464583],
#            [   1.79607292],
#            ...,
#            [1198.46973958],
#            [1198.48623958],
#            [1198.548     ]])}},
#   ['EEG', 'EG2', 'position', 't4c1', 't4c2', 't4c4'],
#   {'rat_id': '11265', 'session': '16030611'}]]
