# %%
import numpy as np
import sys
sys.path.append("../")
import matplotlib.pyplot as plt
from environments.environments.simple2d import Simple2D, Sargolini2006, BasicSargolini2006

# %%
room_width = 15
room_depth = 7
env_name = "env_example"
time_step_size = 0.1 #seg
agent_step_size = 0.5

# Init environment
env = Simple2D(environment_name=env_name,
               room_width = room_width,
               room_depth = room_depth,
               time_step_size = time_step_size,
               agent_step_size = agent_step_size)

# %%
# Create random agent
class RandomAgent(object):
    
    def act(self, observation):
        return np.random.normal(scale=0.1, size=(2,))
    
agent = RandomAgent()

# %%
n_steps = 1000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
env.state_dims_labels
# Out:
# ['x_pos', 'y_pos']

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()
# Out:
# [0 0]

# %%
data_path = "experiment_data/Sargolini2006/"
env = BasicSargolini2006(data_path = data_path, 
                         time_step_size = 0.1,
                         agent_step_size = None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-efc1bd4350f5> in <module>
#       2 env = BasicSargolini2006(data_path = data_path,
#       3                          time_step_size = 0.1,
# ----> 4                          agent_step_size = None)
#
# ~/SSD/Projects/EHC_model_comparison/environments/environments/simple2d.py in __init__(self, data_path, environment_name, **env_kwargs)
#      90         self.data_path = data_path
#      91         self.environment_name = environment_name
# ---> 92         self.data = SargoliniData(data_path=self.data_path, experiment_name=self.environment_name)
#      93         self.arena_limits = self.data.arena_limits
#      94         limits = np.abs(np.diff(self.arena_limits, axis=1))
#
# ~/SSD/Projects/EHC_model_comparison/environments/experiments/behavioral_data.py in __init__(self, data_path, experiment_name)
#     124         self.experiment_name = experiment_name
#     125         if self.experiment_name == "Sargolini2006":
# --> 126             self.arena_limits, self.position, self.head_direction = self.get_sargolini_data()
#     127
#     128     def get_sargolini_data(self):
#
# ~/SSD/Projects/EHC_model_comparison/environments/experiments/behavioral_data.py in get_sargolini_data(self)
#     134         y_position = np.array([])
#     135         for i in range(61):
# --> 136             aux_x = np.load(filenames_x + str(i) + ".npy")
#     137             aux_y = np.load(filenames_y + str(i) + ".npy")
#     138             x_position = np.concatenate([x_position, aux_x])
#
# ~/anaconda3/envs/fresh/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     414             own_fid = False
#     415         else:
# --> 416             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     417             own_fid = True
#     418
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiment_data/sargolini2006/sargolini_x_pos_0.npy'

# %%
n_steps = 10000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.savefig("BasicSargolini.pdf", bbox_inches="tight")
plt.show()

# %%
data_path = "/home/rodrigo/HDisk/8F6BE356-3277-475C-87B1-C7A977632DA7_1/all_data/"

session = {"rat_id": "11016", "sess": "31010502"}

env = Sargolini2006(data_path = data_path,
                    verbose = True,
                    session = session,
                    time_step_size = None,
                    agent_step_size = None)

# %%
n_steps = 10000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()

# %%
env.data.plot_session()
