# %% [markdown]
# ## UniReps and NeuroAI Meeting

# %% [markdown]
# ## Here we import some stuff

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Now we make a plot

# %%
x = np.linspace(-2, 2, 1000)
center = -0
offset = -1
gain = 1
y = gain*(x-center)**2 + offset

# %%
plt.plot(x, y)
plt.show()
