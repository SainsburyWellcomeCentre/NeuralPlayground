# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from sehec.envs.arenas.connected_rooms import ConnectedRooms
from sehec.utils import RandomAgent

# %%
env_name = "env_example"
time_step_size = 0.1 #seg
agent_step_size = 3

# Init environment
env = ConnectedRooms(environment_name=env_name,
                     time_step_size = time_step_size,
                     agent_step_size = agent_step_size)

# %%
agent = RandomAgent()

# %%
n_steps = 10000

# Initialize environment
obs, state = env.reset()
for i in range(n_steps):
    # Observe to choose an action
    action = agent.act(obs)
    # Run environment for given action
    obs, state, reward = env.step(action)

# %%
env.state_dims_labels
# Out:
# ['x_pos', 'y_pos']

# %%
ax = env.plot_trajectory()
fontsize = 16
ax.grid()
# ax.legend(fontsize=fontsize, loc="upper left")
ax.set_xlabel("width", fontsize=fontsize)
ax.set_ylabel("depth", fontsize=fontsize)
plt.show()
# Out:
# [0 0]

# %% [markdown]
# ## Other room shapes
